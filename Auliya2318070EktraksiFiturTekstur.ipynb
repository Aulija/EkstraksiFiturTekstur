# %% [markdown]
# # **1. Mount Google Drive**

# %%
#Untuk mengkoneksikan Google Colab dengan Folder Google Drive
from google.colab import drive
#Untuk memulai proses mounting dari google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **2. Load Data 10 File Citra yang ada pada File Google Drive**

# %%
#Melakukan import library os untuk membuat dan menghapus direktori, mengambil isi direktori, dll
import os

#Mendefinisikan variabel untuk menyimpan lokasi folder citra di dalam Google Drive
folder_path = '/content/drive/MyDrive/Colab Notebooks/CitraBatik'

#Untuk mengubah direktori sesuai dengan nilai variabel folder_path
os.chdir(folder_path)

#Melakukan perulangan dengan kondisi akhir sesuai jumlah isi file di dalam folder
for file_name in os.listdir(folder_path):
    #Mencetak pesan nama file yang ada di dalam folder
    print(f"Nama File: {file_name}")
# Out:
# Nama File: Parang.jpg
# Nama File: Kawung.jpg
# Nama File: MegaMendung.jpg
# Nama File: Sidomukti.jpg
# Nama File: Lasem.jpg
# Nama File: SekarJagad.jpg
# Nama File: Gentongan.jpg
# Nama File: Garut.jpg
# Nama File: Jlamprang.jpg
# Nama File: Bali.jpg

# %% [markdown]
# # **3. Melakukan Konversi Citra BGR ke Grayscale**

# %%
#Melakukan import library opencv yang digunakan untuk melakukan konversi color space
import cv2

#Mendefinisikan variabel untuk menyimpan lokasi folder citra di dalam Google Drive
folder_path = '/content/drive/MyDrive/Colab Notebooks/CitraBatik'

#Melakukan perulangan dengan kondisi akhir sesuai jumlah isi file di dalam folder
for file_name in os.listdir(folder_path):
    #Menentukan spesifikasi file citra yang akan digunakan, yaitu yang memiliki ekstensi.jpg, .jpeg, dan .png
    if file_name.endswith('.jpg') or file_name.endswith('.jpeg') or file_name.endswith('.png'):
        #Membaca file citra yang ada di dalam folder Google Drive
        image = cv2.imread(os.path.join(folder_path, file_name))
        #Melakukan konversi citra dari BGR menjadi Grayscale
        grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        #Menyimpan dan mendefinisikan nama file citra hasil konversi ke dalam folder Google Drive
        cv2.imwrite(os.path.join(folder_path, f"grayscale_{file_name}"), grayscale_image)
        #Mencetak pesan berhasil mengkonversi citra
        print(f'File {file_name} berhasil diubah menjadi grayscale.')
# Out:
# File Parang.jpg berhasil diubah menjadi grayscale.
# File Kawung.jpg berhasil diubah menjadi grayscale.
# File MegaMendung.jpg berhasil diubah menjadi grayscale.
# File Sidomukti.jpg berhasil diubah menjadi grayscale.
# File Lasem.jpg berhasil diubah menjadi grayscale.
# File SekarJagad.jpg berhasil diubah menjadi grayscale.
# File Gentongan.jpg berhasil diubah menjadi grayscale.
# File Garut.jpg berhasil diubah menjadi grayscale.
# File Jlamprang.jpg berhasil diubah menjadi grayscale.
# File Bali.jpg berhasil diubah menjadi grayscale.

# %% [markdown]
# # **4. Melakukan Ekstraksi Fitur Tekstur pada 10 Citra**

# %%
#Melakukan import library os untuk membuat dan menghapus direktori, mengambil isi direktori, dll
import os
#Melakukan import library opencv yang digunakan untuk melakukan konversi color space
import cv2
#Melakukan import library NumPy yang digunakan untuk membentuk objek N-dimensional array
import numpy as np
#Melakukan import graycomatrix untuk menghitung matriks co-occurance tingkat keabuan, dan graycoprops untuk menghitung properti tekstur dari GLCM dari library skimage.feature
from skimage.feature import graycomatrix, graycoprops
#Melakukan import library Pandas yang digunakan untuk membaca isi file excel
import pandas as pd

#Mendefinisikan variabel untuk menyimpan lokasi folder citra di dalam Google Drive
folder_path = '/content/drive/MyDrive/Colab Notebooks/CitraBatik'
#Membuat variabel array kosong yang akan digunakan untuk menampung nilai fitur hasil ekstraksi
nilai_fitur = []

#Melakukan perulangan dengan kondisi akhir sesuai jumlah isi file di dalam folder
for file_name in os.listdir(folder_path):
    #Menentukan spesifikasi file citra yang akan digunakan, yaitu yang memiliki ekstensi.jpg, .jpeg, dan .png
    if file_name.endswith(".jpg") or file_name.endswith('.jpeg') or file_name.endswith(".png"):
        #Membaca file citra yang ada di dalam folder Google Drive
        image = cv2.imread(os.path.join(folder_path, file_name))
        #Melakukan konversi citra dari BGR menjadi Grayscale
        grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        #Menghitung matriks co-occurance dari citra hasil konversi
        glcm = graycomatrix(grayscale_image, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4], symmetric=True, normed=True)
        #Menghitung rata-rata properti tekstur energi dari GLCM
        energi = graycoprops(glcm, 'energy').mean()
        #Menghitung rata-rata properti tekstur kontras dari GLCM
        kontras = graycoprops(glcm, 'contrast').mean()
        #Menghitung rata-rata properti tekstur korelasi dari GLCM
        korelasi = graycoprops(glcm, 'correlation').mean()
        #Menghitung rata-rata properti tekstur homogenitas dari GLCM
        homogenitas = graycoprops(glcm, 'homogeneity').mean()
        #Menampung nilai fitur ke dalam variabel array nilai_fitur
        nilai_fitur.append([file_name, energi, kontras, korelasi, homogenitas])

        #Mencetak nama file
        print(f"File {file_name}:")
        #Mencetak nilai energi
        print(f"Energi: {energi:.3f}")
        #Mencetak nilai kontras
        print(f"Kontras: {kontras:.3f}")
        #Mencetak nilai korelasi
        print(f"Korelasi: {korelasi:.3f}")
        #Mencetak nilai homogenitas
        print(f"Homogenitas: {homogenitas:.3f}")
    else:
        #Mencetak nama file jika bukan gambar
        print(f"Nama File: {file_name}")
# Out:
# File Parang.jpg:
# Energi: 0.011
# Kontras: 1138.804
# Korelasi: 0.902
# Homogenitas: 0.078
# File Kawung.jpg:
# Energi: 0.018
# Kontras: 560.213
# Korelasi: 0.950
# Homogenitas: 0.103
# File MegaMendung.jpg:
# Energi: 0.024
# Kontras: 161.217
# Korelasi: 0.985
# Homogenitas: 0.279
# File Sidomukti.jpg:
# Energi: 0.009
# Kontras: 978.391
# Korelasi: 0.819
# Homogenitas: 0.068
# File Lasem.jpg:
# Energi: 0.012
# Kontras: 2251.171
# Korelasi: 0.760
# Homogenitas: 0.068
# File SekarJagad.jpg:
# Energi: 0.009
# Kontras: 1325.396
# Korelasi: 0.824
# Homogenitas: 0.065
# File Gentongan.jpg:
# Energi: 0.006
# Kontras: 2218.765
# Korelasi: 0.555
# Homogenitas: 0.034
# File Garut.jpg:
# Energi: 0.019
# Kontras: 278.275
# Korelasi: 0.910
# Homogenitas: 0.130
# File Jlamprang.jpg:
# Energi: 0.010
# Kontras: 644.135
# Korelasi: 0.837
# Homogenitas: 0.086
# File Bali.jpg:
# Energi: 0.010
# Kontras: 589.975
# Korelasi: 0.842
# Homogenitas: 0.073
# File grayscale_Parang.jpg:
# Energi: 0.011
# Kontras: 1142.291
# Korelasi: 0.902
# Homogenitas: 0.076
# File grayscale_Kawung.jpg:
# Energi: 0.018
# Kontras: 561.862
# Korelasi: 0.950
# Homogenitas: 0.102
# File grayscale_MegaMendung.jpg:
# Energi: 0.024
# Kontras: 161.360
# Korelasi: 0.985
# Homogenitas: 0.279
# File grayscale_Sidomukti.jpg:
# Energi: 0.009
# Kontras: 982.512
# Korelasi: 0.818
# Homogenitas: 0.066
# File grayscale_Lasem.jpg:
# Energi: 0.012
# Kontras: 2256.278
# Korelasi: 0.760
# Homogenitas: 0.065
# File grayscale_SekarJagad.jpg:
# Energi: 0.009
# Kontras: 1328.959
# Korelasi: 0.824
# Homogenitas: 0.064
# File grayscale_Gentongan.jpg:
# Energi: 0.006
# Kontras: 2210.275
# Korelasi: 0.557
# Homogenitas: 0.034
# File grayscale_Garut.jpg:
# Energi: 0.019
# Kontras: 279.535
# Korelasi: 0.910
# Homogenitas: 0.129
# File grayscale_Jlamprang.jpg:
# Energi: 0.010
# Kontras: 646.782
# Korelasi: 0.837
# Homogenitas: 0.086
# File grayscale_Bali.jpg:
# Energi: 0.010
# Kontras: 593.180
# Korelasi: 0.842
# Homogenitas: 0.073

# %% [markdown]
# # **5. Melakukan Penampungan Nilai-Nilai Fitur ke dalam File .xlsx dan Membuka isi File .xlsx**

# %%
#Mendefinisikan variabel untuk menyimpan nama kolom pada excel
nama_kolom = ['Nama File', 'Energi', 'Kontras', 'Korelasi', 'Homogenitas']
#Menyimpan nilai-nilai hasil ekstraksi fitur ke dalam dataframe
fitur_dataframe = pd.DataFrame(nilai_fitur, columns=nama_kolom)

#Mendefinisikan variabel untuk menyimpan nama dan ekstensi file
nama_file = '2318070_HasilEkstraksiFitur.xlsx'
#Menyimpan dataframe ke dalam file excel dengan nama sesuai dengan variabel nama_file
fitur_dataframe.to_excel(nama_file, index=False)

#Mencetak pesan bahwa file berhasil disimpan
print(f'File {nama_file} Berhasil Disimpan.')

#Membaca file excel yang sudah dibuat
excel = pd.read_excel('2318070_HasilEkstraksiFitur.xlsx')

#Mencetak isi dari file excel
print(excel)
# Out:
# File 2318070_HasilEkstraksiFitur.xlsx Berhasil Disimpan.
#                     Nama File    Energi      Kontras  Korelasi  Homogenitas
# 0                  Parang.jpg  0.011495  1138.803528  0.902410     0.077888
# 1                  Kawung.jpg  0.018008   560.212550  0.949770     0.102565
# 2             MegaMendung.jpg  0.023859   161.216707  0.984888     0.279442
# 3               Sidomukti.jpg  0.009395   978.391198  0.819005     0.067726
# 4                   Lasem.jpg  0.012435  2251.171362  0.760307     0.067633
# 5              SekarJagad.jpg  0.008714  1325.396062  0.823907     0.064696
# 6               Gentongan.jpg  0.006486  2218.764536  0.555474     0.033788
# 7                   Garut.jpg  0.019437   278.274771  0.910380     0.129636
# 8               Jlamprang.jpg  0.010207   644.134869  0.837460     0.086394
# 9                    Bali.jpg  0.009727   589.974655  0.842425     0.073419
# 10       grayscale_Parang.jpg  0.011259  1142.290524  0.902170     0.075751
# 11       grayscale_Kawung.jpg  0.017987   561.861674  0.949647     0.102194
# 12  grayscale_MegaMendung.jpg  0.023826   161.360377  0.984878     0.278829
# 13    grayscale_Sidomukti.jpg  0.009300   982.512204  0.818472     0.065871
# 14        grayscale_Lasem.jpg  0.012228  2256.277778  0.759947     0.065418
# 15   grayscale_SekarJagad.jpg  0.008693  1328.959335  0.823609     0.064346
# 16    grayscale_Gentongan.jpg  0.006494  2210.275482  0.556719     0.033843
# 17        grayscale_Garut.jpg  0.019372   279.534798  0.910041     0.129049
# 18    grayscale_Jlamprang.jpg  0.010183   646.782287  0.836995     0.085812
# 19         grayscale_Bali.jpg  0.009710   593.179913  0.841802     0.073120
